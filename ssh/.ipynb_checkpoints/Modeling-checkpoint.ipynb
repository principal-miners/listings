# %% [markdown]
# # AirBnb listings file modeling

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
from IPython.core.display import display, HTML
import pandas as pd
import warnings
import ast
warnings.filterwarnings('ignore')

# %reload_ext autoreload
# %autoreload 1
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import seaborn as sns
import pandas as pd
import math

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error as MSE

from imblearn.over_sampling import SMOTE

from Utils.UtilsGeoViz import *
from Utils.UtilsViz import *
from Utils.DataUtils import *

RANDOM_SEED = 42

# %%
data_path = os.path.join(os.getcwd(), "../data/cleaned_listings.csv")
listings = pd.read_csv(data_path, index_col="id")
display(listings.shape)
# Out:
# (48855, 80)

# %% [markdown]
# ### Plot the dstribution

# %% [markdown]
# Let's plot the percentile for price

# %%
percentiles = list(range(0,101, 1))
price_percentile = {}
for p in percentiles:
    price_percentile[p] = np.percentile(listings['price'].values, p)

price_percentile = pd.DataFrame.from_dict(price_percentile, orient='index')
price_percentile.plot(kind='bar', figsize=(25,9), grid=True, legend=False)
plt.title("Percentile distribution of price")
plt.xlabel("Percentile")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
f, ax = plt.subplots(1,1,figsize=(30,9))
g = sns.countplot(x="price", data=listings, ax=ax)
t = g.set_xticklabels(g.get_xticklabels(), rotation=90)
t = g.set_title("price distribution")
median_idx = np.where(np.sort(listings["price"].unique())==listings["price"].median())
plt.axvline(x=median_idx, linestyle="-.")
percentile_75_idx = np.where(np.sort(listings["price"].unique())==price_percentile.iloc[75,:].values[0])
plt.axvline(x=percentile_75_idx, linestyle="--")
percentile_90_idx = np.where(np.sort(listings["price"].unique())==price_percentile.iloc[90,:].values[0])
plt.axvline(x=percentile_90_idx, linestyle=":")

# %% [markdown]
# ------------------

# %% [markdown]
# Quick helper functions

# %%
def roundto(row, base=5):
    return int(base * round(float(row) / base))

# %% [markdown]
# # Synthetic sample generation

# %% [markdown]
# ### 1. Train test split

# %%
train, test = train_test_split(listings, test_size=0.2, random_state=RANDOM_SEED)

# %% [markdown]
# ### 2. Oversampling using SMOTE

# %%
def check_rep(row):
    if (row <= 200) | (row==250) | (row==350) | (row==450) | (row==550) :
        return 0
    elif (row > 200) & (row < 300) & (row != 250):
        return 1 
    elif (row > 300) & (row < 400) & (row != 350):
        return 2 
    else:
        return 3 

train["flag_ur"] = train["price"].apply(check_rep)

# %%
vcs = train["flag_ur"].value_counts()
vcs
# Out:
# 0    34674
# 1     2455
# 3     1313
# 2      642
# Name: flag_ur, dtype: int64

# %%
ycol = ["flag_ur"]
xcol = [i for i in train.columns if i not in ycol]

x = train[xcol].values
y = train[ycol].values

smote_sampling_strategy = {
    1: int(vcs[1]*4)
    ,2: int(vcs[1]*2)
    ,3: int(vcs[1]*2)
}
sm = SMOTE(random_state=RANDOM_SEED, sampling_strategy=smote_sampling_strategy, n_jobs=-1)

x_new, y_new = sm.fit_sample(x, y)

# Drop the flag column
train.drop(labels=["flag_ur"], axis=1, inplace=True)

# Get the index of the price columns
def get_index(vallist, val):
    return vallist.index(val)

price_index = get_index(list(train.columns), "price")

y = x_new[:, price_index]
x_train = np.delete(x_new, price_index, axis=1)

y_new = []
for elem in y:
    y_new.append(roundto(elem))

y_train = y_new

# %%
print(
"New size :", x_train.shape, "\n",
"Old size :", train.shape,
)
# Out:
# New size : (54314, 79)
#  Old size : (39084, 80)

# %%
f, ax = plt.subplots(1, 2, figsize=(30, 9), sharey=True)
g1 = sns.distplot(train["price"], ax=ax[0], kde=False)
t = g1.set_title("Original price distribution")

g2 = sns.distplot(y, ax=ax[1], kde=False)
t = g2.set_title("SMOTE price distribution")

# %% [markdown]
# ### 3. Standardisation

# %%
standard_scaler = StandardScaler()
x_train = standard_scaler.fit_transform(x_train)

# %%
# Get the index of the price columns
def get_index(vallist, val):
    return vallist.index(val)

price_index = get_index(list(test.columns), "price")

x_tmp = test.values
y_test = x_tmp[:, price_index]
x_test = np.delete(x_tmp, price_index, axis=1)

y_tmp = []
for elem in y_test:
    y_tmp.append(roundto(elem))

y_test = y_tmp

x_test = standard_scaler.transform(x_test)

# %% [markdown]
# ### 4. Transformation

# %%
pca_naive = PCA(n_components=None)
pca_naive.fit(x_train)
f, ax = plt.subplots(1,2,figsize=(20,5))
plot_naive_variance(pca_naive, ax[0])
num_pc = plot_pca_var_cum(pca_naive, ax=ax[1], cutoff=0.95)

# %%
# pca = PCA(n_components=num_pc)
pca = PCA(n_components=None)
pca.fit(x_train)
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Random Forest Regressor

# %% [markdown]
# #### With PCA

# %%
rfr = RandomForestRegressor()
rfr.fit(X=x_train_pca, y=y_train)
y_pred_train = rfr.predict(X=x_train_pca)
y_pred_test = rfr.predict(X=x_test_pca)

mse_train = MSE(y_train, y_pred_train)
mse_test = MSE(y_test, y_pred_test)

rmse_train = mse_train**(1/2)
rmse_test = mse_test**(1/2)

print("Train set RMSE: {:.2f}".format(rmse_train))
print("Test set RMSE: {:.2f}".format(rmse_test))
# Out:
# Train set RMSE: 25.72
# Test set RMSE: 62.48

# %%
f, ax = plt.subplots(1,1, figsize=(30, 9))
g = sns.pointplot(x=y_test, y=y_pred_test, ax=ax, color="red")
g = sns.pointplot(x=y_train, y=y_pred_train, ax=ax)

t = g.set_xlabel("Price")
t = g.set_ylabel("Predicted price distribution")
t = g.set_xticklabels(g.get_xticklabels(), rotation=90)
t = g.set_title("PCA")

# %%
rfr = RandomForestRegressor()
rfr.fit(X=x_train, y=y_train)
y_pred_train = rfr.predict(X=x_train)
y_pred_test = rfr.predict(X=x_test)

mse_train = MSE(y_train, y_pred_train)
mse_test = MSE(y_test, y_pred_test)

rmse_train = mse_train**(1/2)
rmse_test = mse_test**(1/2)

print("Train set RMSE: {:.2f}".format(rmse_train))
print("Test set RMSE: {:.2f}".format(rmse_test))
# Out:
# Train set RMSE: 22.81
# Test set RMSE: 55.05

# %%
f, ax = plt.subplots(1,1, figsize=(30, 9))
g = sns.pointplot(x=y_test, y=y_pred_test, ax=ax, color="red")
g = sns.pointplot(x=y_train, y=y_pred_train, ax=ax)

t = g.set_xlabel("Price")
t = g.set_ylabel("Predicted price distribution")
t = g.set_xticklabels(g.get_xticklabels(), rotation=90)
t = g.set_title("Normal")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-34e9a73502fb> in <module>
#       1 f, ax = plt.subplots(1,1, figsize=(30, 9))
# ----> 2 g = sns.pointplot(x=listings["price"].unique(), y=y_pred_test, ax=ax, color="red")
#       3 g = sns.pointplot(x=listings["price"].unique(), y=y_pred_train, ax=ax)
#       4
#       5 t = g.set_xlabel("Price")
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3333                             estimator, ci, n_boot, units,
#    3334                             markers, linestyles, dodge, join, scale,
# -> 3335                             orient, color, palette, errwidth, capsize)
#    3336
#    3337     if ax is None:
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize)
#    1676         """Initialize the plotter."""
#    1677         self.establish_variables(x, y, hue, data, orient,
# -> 1678                                  order, hue_order, units)
#    1679         self.establish_colors(color, palette, 1)
#    1680         self.estimate_statistic(estimator, ci, n_boot)
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     205                 # Group the numeric data
#     206                 plot_data, value_label = self._group_longform(vals, groups,
# --> 207                                                               group_names)
#     208
#     209                 # Now handle the hue levels for nested ordering
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in _group_longform(self, vals, grouper, order)
#     247
#     248         # Group the val data
# --> 249         grouped_vals = vals.groupby(grouper)
#     250         out_data = []
#     251         for g in order:
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     600                          observed=observed,
#     601                          in_axis=in_axis)
# --> 602                 if not isinstance(gpr, Grouping) else gpr)
#     603
#     604         groupings.append(ping)
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     237         self.name = name
#     238         self.level = level
# --> 239         self.grouper = _convert_grouper(index, grouper)
#     240         self.all_grouper = None
#     241         self.index = index
#
# c:\users\sriharis\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\grouper.py in _convert_grouper(axis, grouper)
#     627     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#     628         if len(grouper) != len(axis):
# --> 629             raise ValueError('Grouper and axis must be same length')
#     630         return grouper
#     631     else:
#
# ValueError: Grouper and axis must be same length
