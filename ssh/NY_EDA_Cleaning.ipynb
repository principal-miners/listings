# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
from IPython.core.display import display, HTML
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %reload_ext autoreload
# %autoreload 1
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import seaborn as sns
import pandas as pd
import math

from Utils.UtilsGeoViz import *
from Utils.UtilsViz import *
from Utils.DataUtils import *

# %%
US_coord = [37.0902, -102]
NY_COORD = [40.7128, -74.0060]

data_path = os.path.join(os.getcwd(), "Data")
ch_datapath = os.path.join(data_path, "NY")

# %%
listings = pd.read_csv(os.path.join(ch_datapath, "listings.csv"))

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50228 entries, 0 to 50227
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(22), int64(21), object(63)
# memory usage: 28.5+ MB

# %%
def remove_childlist_from_parentlist(parent, child):
    return [x for x in parent if x not in child]

# %%
rows_to_drop = listings[listings['host_listings_count'] != listings['host_total_listings_count']].index
listings.drop(index=rows_to_drop,axis=0,inplace=True)

# %%
monu_cols_to_clean = ['id','host_response_time', 'host_response_rate',
       'host_is_superhost', 
       'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified',
       'is_location_exact', 'property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
       'price', 'weekly_price', 'monthly_price', 'security_deposit',
       'cleaning_fee', 'guests_included', 'extra_people','instant_bookable',
       'is_business_travel_ready', 'cancellation_policy',
       'require_guest_profile_picture', 'require_guest_phone_verification',
       'calculated_host_listings_count', 'reviews_per_month']

cols_to_drop = ['listing_url','scrape_id', 'last_scraped','experiences_offered', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id',
               'host_url', 'host_name', 'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'street',
               'license']

col_list_1 = find_unique_elems([listings.columns, monu_cols_to_clean])

nlp_cols = \
['jurisdiction_names',
 'notes',
 'interaction',
 'access',
 'house_rules',
 'neighborhood_overview',
 'host_about',
 'transit',
 'space',
 'summary',
 'name',
 'description']

ssh_cols_to_clean = remove_childlist_from_parentlist(col_list_1, cols_to_drop)
ssh_cols_to_clean = remove_childlist_from_parentlist(ssh_cols_to_clean, nlp_cols)

# %% [markdown]
# --------------------------------------------

# %%
nlp_listings = listings[nlp_cols]
plot_nans(nlp_listings)

# %%
nlp_lencols = ["description", "host_about"]
nlp_listings["description"].fillna("", inplace=True)
nlp_listings["host_about"].fillna("", inplace=True)

nlp_listings["description"] = nlp_listings["description"].astype(str)
nlp_listings["host_about"] = nlp_listings["host_about"].astype(str)

nlp_listings["desc_len"] = nlp_listings["description"].apply(len)
nlp_listings["host_about_len"] = nlp_listings["host_about"].apply(len)

# %%
nlp_len_cols = ["description", "host_about", "desc_len", "host_about_len"]
nlp_listings[nlp_len_cols].head()
# Out:
#                                          description                                         host_about  desc_len                                     host_about_len
# 0  Great light, exposed brick and 10 feet high ce...                                                          412  <bound method _noarg_wrapper.<locals>.wrapper ...
# 1  Renovated apt home in elevator building. Spaci...  Educated professional living in Brooklyn.  I l...       392  <bound method _noarg_wrapper.<locals>.wrapper ...
# 2  Find your romantic getaway to this beautiful, ...  A New Yorker since 2000! My passion is creatin...      1000  <bound method _noarg_wrapper.<locals>.wrapper ...
# 3  This is a spacious, clean, furnished master be...                          From Brooklyn with love.       1000  <bound method _noarg_wrapper.<locals>.wrapper ...
# 4  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...  Make Up Artist National/ (Website hidden by Ai...      1000  <bound method _noarg_wrapper.<locals>.wrapper ...

# %% [markdown]
# -------------

# %%
cols_to_drop
# Out:
# ['listing_url',
#  'scrape_id',
#  'last_scraped',
#  'experiences_offered',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_acceptance_rate',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'street',
#  'license']

# %%
listings = listings[ssh_cols_to_clean]

# %%
def plot_nans(df):
    nan_df = analyse_nans(df)
    nan_df_transpose = nan_df.T
    nan_df_transpose.sort_values(by="percentage", ascending=False, axis=0, inplace=True)
    f, ax = plt.subplots(1,1, figsize=(30,5))
    plot_bar(data=nan_df_transpose, x=nan_df_transpose.index, y="percentage", 
             ax=ax, annot=True, highlight_max_min=False,
             xlabel="Column", ylabel="Percentage", title="Percentage of NaNs in each column",
            xrot=90)

# %%
plot_nans(listings)

# %% [markdown]
# ##### Make placeholders

# %%
more_cols_to_drop = []

# %% [markdown]
# -----------------------------------

# %%
listings.head()
# Out:
#   has_availability neighbourhood_cleansed  maximum_minimum_nights  maximum_nights_avg_ntm neighbourhood_group_cleansed first_review  review_scores_communication  review_scores_rating  minimum_nights_avg_ntm  number_of_reviews_ltm calendar_last_scraped  availability_30  calculated_host_listings_count_shared_rooms  calculated_host_listings_count_entire_homes    market  availability_90  number_of_reviews  maximum_maximum_nights requires_license        country  minimum_minimum_nights   latitude  maximum_nights neighbourhood       city  review_scores_location                      host_location state  review_scores_cleanliness  availability_60 country_code  review_scores_accuracy  review_scores_checkin  minimum_nights  minimum_maximum_nights calendar_updated smart_location  host_since  longitude  review_scores_value  calculated_host_listings_count_private_rooms  availability_365 host_neighbourhood last_review zipcode
# 0                t                Midtown                       7                   730.0                    Manhattan   2019-01-30                          NaN                   NaN                     7.0                      1            2019-02-01               16                                            0                                            1  New York               65                  1                     730                f  United States                       7  40.755523             730  Midtown East   New York                     NaN                                 US    NY                        NaN               36           US                     NaN                    NaN               7                     730       2 days ago   New York, NY  2008-09-03 -73.967679                  NaN                                             0                65       Midtown East  2019-01-30   10022
# 1                t             Kensington                       1                   730.0                     Brooklyn   2015-12-04                         10.0                  98.0                     1.0                      2            2019-02-02               30                                            3                                            0  New York               90                  9                     730                f  United States                       1  40.647486             730    Kensington  Brooklyn                     10.0  New York, New York, United States    NY                       10.0               60           US                    10.0                   10.0               1                     730       4 days ago  Brooklyn , NY  2008-09-07 -73.972370                 10.0                                             5               365          Gravesend  2018-10-19   11218
# 2                t                Midtown                       1                  1125.0                    Manhattan   2009-11-21                         10.0                  95.0                     1.0                     14            2019-02-02               30                                            1                                            1  New York               90                 43                    1125                f  United States                       1  40.753621            1125       Midtown   New York                    10.0  New York, New York, United States    NY                        9.0               60           US                     9.0                   10.0               1                    1125       a week ago   New York, NY  2008-09-09 -73.983774                  9.0                                             0               365            Midtown  2019-01-02   10018
# 3                t           Williamsburg                       5                   730.0                     Brooklyn   2010-01-04                         10.0                  97.0                     5.0                     12            2019-02-02                2                                            0                                            0  New York               37                 39                     730                f  United States                       5  40.708558             730  Williamsburg   Brooklyn                    10.0  New York, New York, United States    NY                       10.0               27           US                    10.0                   10.0               5                     730      2 weeks ago   Brooklyn, NY  2008-11-09 -73.942362                 10.0                                             3               290  East Williamsburg  2018-12-07   11206
# 4                t                 Harlem                       3                     7.0                    Manhattan          NaN                          NaN                   NaN                     3.0                      0            2019-02-02               30                                            0                                            0  New York               90                  0                       7                f  United States                       3  40.809018               7        Harlem   New York                     NaN  New York, New York, United States    NY                        NaN               60           US                     NaN                    NaN               3                       7    29 months ago   New York, NY  2008-11-25 -73.941902                  NaN                                             1               365             Harlem         NaN   10027

# %%
listings.shape
# Out:
# (50220, 45)

# %% [markdown]
# ## Country

# %%
listings["country"].value_counts()
# Out:
# United States    50220
# Name: country, dtype: int64

# %%
listings["Peru"==listings["country"]]
# Out:
# Empty DataFrame
# Columns: [has_availability, neighbourhood_cleansed, maximum_minimum_nights, maximum_nights_avg_ntm, neighbourhood_group_cleansed, first_review, review_scores_communication, review_scores_rating, minimum_nights_avg_ntm, number_of_reviews_ltm, calendar_last_scraped, availability_30, calculated_host_listings_count_shared_rooms, calculated_host_listings_count_entire_homes, market, availability_90, number_of_reviews, maximum_maximum_nights, requires_license, country, minimum_minimum_nights, latitude, maximum_nights, neighbourhood, city, review_scores_location, host_location, state, review_scores_cleanliness, availability_60, country_code, review_scores_accuracy, review_scores_checkin, minimum_nights, minimum_maximum_nights, calendar_updated, smart_location, host_since, longitude, review_scores_value, calculated_host_listings_count_private_rooms, availability_365, host_neighbourhood, last_review, zipcode]
# Index: []

# %% [markdown]
# Drop column? Peru seems to be an outlier. listings url is also invalid when checked.

# %% [markdown]
# ## Review scores

# %% [markdown]
# Hypothesis: Most rows in the <b>review_scores_*</b> columns that have NaNs, have them for all the <b>review_scores_*</b> columns in that particular row.
#
#
# i.e., if *review_scores_value* has a NaN, then so will *review_scores_location* and the other *review_scores_* columns.
#
# Let's verify this by finding the columns that are NOT NaNs throughout all the review_scores_* columns.

# %%
review_scores_cols = ['review_scores_value', 'review_scores_location', 'review_scores_checkin', 'review_scores_cleanliness', 'review_scores_communication', 'review_scores_accuracy', 'review_scores_rating']
nan_df = analyse_nans(listings[review_scores_cols])


# Verify that these columns have missing values in the exact same rows.
print("Number of rows between pairs of columns that have NaNs only in one of them - ")
for i in range(1, len(review_scores_cols)):
    print(review_scores_cols[i], "\t", review_scores_cols[i-1], end=" -->\t ")
    idx1 = nan_df[review_scores_cols[i-1]].iloc[2]
    idx2 = nan_df[review_scores_cols[i]].iloc[2]
    l = find_unique_elems([idx1, idx2])
    print(len(l), "rows, \ti.e.", round(100*len(l)/listings.shape[0], 2), "% of total listings rows")
# Out:
# Number of rows between pairs of columns that have NaNs only in one of them -
# review_scores_location 	 review_scores_value -->	 17 rows, 	i.e. 0.03 % of total listings rows
# review_scores_checkin 	 review_scores_location -->	 19 rows, 	i.e. 0.04 % of total listings rows
# review_scores_cleanliness 	 review_scores_checkin -->	 43 rows, 	i.e. 0.09 % of total listings rows
# review_scores_communication 	 review_scores_cleanliness -->	 28 rows, 	i.e. 0.06 % of total listings rows
# review_scores_accuracy 	 review_scores_communication -->	 31 rows, 	i.e. 0.06 % of total listings rows
# review_scores_rating 	 review_scores_accuracy -->	 47 rows, 	i.e. 0.09 % of total listings rows

# %% [markdown]
# Majority of rows have NaNs throughout all the review_scores_* columns. However, there are a few that don't as well.

# %% [markdown]
# Plot a distribution of Review Scores

# %%
listings[review_scores_cols].describe()
# Out:
#        review_scores_value  review_scores_location  review_scores_checkin  review_scores_cleanliness  review_scores_communication  review_scores_accuracy  review_scores_rating
# count         38848.000000            38847.000000           38852.000000               38889.000000                 38877.000000            38874.000000          38913.000000
# mean              9.376184                9.527016               9.738315                   9.265319                     9.752064                9.605263             93.782695
# std               0.902918                0.776485               0.711515                   1.078683                     0.704248                0.833096              8.468368
# min               2.000000                2.000000               2.000000                   2.000000                     2.000000                2.000000             20.000000
# 25%               9.000000                9.000000              10.000000                   9.000000                    10.000000                9.000000             91.000000
# 50%              10.000000               10.000000              10.000000                  10.000000                    10.000000               10.000000             96.000000
# 75%              10.000000               10.000000              10.000000                  10.000000                    10.000000               10.000000            100.000000
# max              10.000000               10.000000              10.000000                  10.000000                    10.000000               10.000000            100.000000

# %%
# Uncomment these lines to see histograms of the review scores columns
# f, ax = plt.subplots(3,3, figsize=(27,12))
# col_counter = 0
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[0][0])
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[0][1])
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[0][2])
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[1][0])
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[1][1])
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[1][2])
# sns.distplot(a=listings[~listings[review_scores_cols[col_counter]].isna()][review_scores_cols[col_counter]], ax=ax[2][0])
# ax[2][1].set_visible(not ax[2][1].get_visible())
# ax[2][2].set_visible(not ax[2][2].get_visible())

# %% [markdown]
# Well, skewed distributions throughout as expected. Transformations might prove useful here to compensate for the large left skew.

# %% [markdown]
# We could fill the missing values of each columns with the integer part of its median.

# %%
for col in review_scores_cols:
    listings[col].fillna(listings[col].median(), inplace=True)

# %%
plot_nans(listings)

# %% [markdown]
# ##  city, market, zipcode, neighbourhood, host_neighbourhood

# %%
geo_cols = ["city", "neighbourhood","neighbourhood_cleansed", "neighbourhood_group_cleansed", "market", "host_neighbourhood"]
listings[listings["city"].isna()][geo_cols].head()
# Out:
#       city neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed    market host_neighbourhood
# 8208   NaN   Sunset Park            Sunset Park                     Brooklyn  New York        Sunset Park
# 10646  NaN       Astoria                Astoria                       Queens  New York            Astoria
# 10857  NaN           NaN                Astoria                       Queens  New York            Astoria
# 10880  NaN       Astoria                Astoria                       Queens  New York            Astoria
# 10882  NaN           NaN                Astoria                       Queens  New York            Astoria

# %% [markdown]
# ### city

# %%
listings["city"].fillna("NYC", inplace=True)

# %% [markdown]
# ### market

# %%
listings["market"].value_counts()
# Out:
# New York                       50066
# Other (Domestic)                  19
# Adirondacks                        2
# Catskills and Hudson Valley        1
# Los Angeles                        1
# Cuba                               1
# Agra                               1
# Atlanta                            1
# Paris                              1
# San Francisco                      1
# D.C.                               1
# Boston                             1
# Jamaica South Coast                1
# South Bay, CA                      1
# New Orleans                        1
# Kyoto                              1
# Lagos, NG                          1
# Name: market, dtype: int64

# %%
no_geonan_listings = listings[geo_cols].dropna()

# %%
for market in no_geonan_listings["market"].unique():
    print(market, "  -->  ", no_geonan_listings[no_geonan_listings["market"]==market]["neighbourhood_group_cleansed"].unique()[:10])
# Out:
# New York   -->   ['Manhattan' 'Brooklyn' 'Queens' 'Staten Island' 'Bronx']
# Other (Domestic)   -->   ['Queens' 'Brooklyn' 'Manhattan']
# Boston   -->   ['Brooklyn']
# Los Angeles   -->   ['Manhattan']
# Atlanta   -->   ['Brooklyn']
# Paris   -->   ['Brooklyn']
# New Orleans   -->   ['Brooklyn']
# San Francisco   -->   ['Manhattan']
# Cuba   -->   ['Queens']
# D.C.   -->   ['Brooklyn']
# Lagos, NG   -->   ['Brooklyn']
# Agra   -->   ['Manhattan']
# Catskills and Hudson Valley   -->   ['Brooklyn']
# Kyoto   -->   ['Brooklyn']
# Adirondacks   -->   ['Brooklyn']
# Jamaica South Coast   -->   ['Queens']

# %%
map_nbc_market = {}
for nbc in no_geonan_listings["neighbourhood_cleansed"].unique():
    map_nbc_market[nbc] = listings[listings["neighbourhood_cleansed"]==nbc]["market"].unique()

# %%
map_nbc_market
# Out:
# {'Midtown': array(['New York', nan], dtype=object),
#  'Kensington': array(['New York', 'Other (Domestic)'], dtype=object),
#  'Williamsburg': array(['New York', 'D.C.', 'Kyoto', nan], dtype=object),
#  'Harlem': array(['New York', 'Agra', nan], dtype=object),
#  'Clinton Hill': array(['New York', nan], dtype=object),
#  "Hell's Kitchen": array(['New York', nan], dtype=object),
#  'Upper West Side': array(['New York', nan], dtype=object),
#  'Flatiron District': array(['New York', 'Other (Domestic)', nan], dtype=object),
#  'Chinatown': array(['New York'], dtype=object),
#  'Upper East Side': array(['New York', nan, 'Other (Domestic)'], dtype=object),
#  'South Slope': array(['New York'], dtype=object),
#  'West Village': array(['New York', 'San Francisco', nan], dtype=object),
#  'East Harlem': array(['New York', nan], dtype=object),
#  'Fort Greene': array(['New York'], dtype=object),
#  'Chelsea': array(['New York', nan], dtype=object),
#  'Crown Heights': array(['New York', 'Paris', nan], dtype=object),
#  'Park Slope': array(['New York', nan], dtype=object),
#  'East Village': array(['New York', nan], dtype=object),
#  'Bedford-Stuyvesant': array(['New York', 'Atlanta', 'New Orleans', 'Lagos, NG',
#         'Catskills and Hudson Valley', 'Other (Domestic)', nan],
#        dtype=object),
#  'Windsor Terrace': array(['New York', nan], dtype=object),
#  'Inwood': array(['New York'], dtype=object),
#  'Greenpoint': array(['New York', 'Other (Domestic)', nan], dtype=object),
#  'Bushwick': array(['New York', 'Boston', 'Other (Domestic)', nan], dtype=object),
#  'Flatbush': array(['New York'], dtype=object),
#  'Lower East Side': array(['New York', nan], dtype=object),
#  'Prospect-Lefferts Gardens': array(['New York', nan], dtype=object),
#  'Long Island City': array(['New York'], dtype=object),
#  'Kips Bay': array(['New York', nan], dtype=object),
#  'SoHo': array(['New York'], dtype=object),
#  'Prospect Heights': array(['New York'], dtype=object),
#  'Washington Heights': array(['New York', nan], dtype=object),
#  'Woodside': array(['New York', 'Other (Domestic)'], dtype=object),
#  'Brooklyn Heights': array(['New York'], dtype=object),
#  'Carroll Gardens': array(['New York'], dtype=object),
#  'Gowanus': array(['New York'], dtype=object),
#  'Flatlands': array(['New York', nan], dtype=object),
#  'Cobble Hill': array(['New York'], dtype=object),
#  'Flushing': array(['New York', 'Other (Domestic)'], dtype=object),
#  'Boerum Hill': array(['New York'], dtype=object),
#  'Sunnyside': array(['New York', 'Other (Domestic)', nan], dtype=object),
#  'DUMBO': array(['New York'], dtype=object),
#  'St. George': array(['New York'], dtype=object),
#  'Highbridge': array(['New York'], dtype=object),
#  'Ridgewood': array(['New York', 'Other (Domestic)', nan], dtype=object),
#  'Morningside Heights': array(['New York', nan], dtype=object),
#  'Sunset Park': array(['New York', nan], dtype=object),
#  'Middle Village': array(['New York'], dtype=object),
#  'NoHo': array(['New York'], dtype=object),
#  'Roosevelt Island': array(['New York'], dtype=object),
#  'Little Italy': array(['New York'], dtype=object),
#  'East Flatbush': array(['New York', nan], dtype=object),
#  'Tompkinsville': array(['New York'], dtype=object),
#  'Astoria': array(['New York', 'Other (Domestic)', nan], dtype=object),
#  'Clason Point': array(['New York'], dtype=object),
#  'Eastchester': array(['New York'], dtype=object),
#  'Kingsbridge': array(['New York'], dtype=object),
#  'Two Bridges': array(['New York'], dtype=object),
#  'Rockaway Beach': array(['New York'], dtype=object),
#  'Forest Hills': array(['New York', nan], dtype=object),
#  'Murray Hill': array(['New York', nan], dtype=object),
#  'Nolita': array(['New York'], dtype=object),
#  'Greenwich Village': array(['New York', nan], dtype=object),
#  'Woodlawn': array(['New York'], dtype=object),
#  'University Heights': array(['New York'], dtype=object),
#  'Gramercy': array(['New York', 'Los Angeles', nan], dtype=object),
#  'Allerton': array(['New York'], dtype=object),
#  'East New York': array(['New York', nan], dtype=object),
#  'Theater District': array(['New York'], dtype=object),
#  'Concourse Village': array(['New York'], dtype=object),
#  'Sheepshead Bay': array(['New York', nan], dtype=object),
#  'Fort Hamilton': array(['New York'], dtype=object),
#  'Bensonhurst': array(['New York'], dtype=object),
#  'Tribeca': array(['New York', nan], dtype=object),
#  'Shore Acres': array(['New York'], dtype=object),
#  'Concourse': array(['New York'], dtype=object),
#  'Richmond Hill': array(['New York'], dtype=object),
#  'Vinegar Hill': array(['New York'], dtype=object),
#  'Midwood': array(['New York'], dtype=object),
#  'Ditmars Steinway': array(['New York', 'Other (Domestic)', nan], dtype=object),
#  'Jackson Heights': array(['New York'], dtype=object),
#  'Elmhurst': array(['New York'], dtype=object),
#  'Cypress Hills': array(['New York'], dtype=object),
#  'St. Albans': array(['New York', nan], dtype=object),
#  'Arrochar': array(['New York'], dtype=object),
#  'Financial District': array(['New York'], dtype=object),
#  'Rego Park': array(['New York'], dtype=object),
#  'Clifton': array(['New York'], dtype=object),
#  'Bay Ridge': array(['New York'], dtype=object),
#  'Graniteville': array(['New York'], dtype=object),
#  'Stapleton': array(['New York'], dtype=object),
#  'Briarwood': array(['New York'], dtype=object),
#  'Ozone Park': array(['New York', nan], dtype=object),
#  'Columbia St': array(['New York'], dtype=object),
#  'Morris Heights': array(['New York'], dtype=object),
#  'Brighton Beach': array(['New York'], dtype=object),
#  'Longwood': array(['New York'], dtype=object),
#  'Canarsie': array(['New York'], dtype=object),
#  'Jamaica': array(['New York', 'Jamaica South Coast'], dtype=object),
#  'Battery Park City': array(['New York'], dtype=object),
#  'Civic Center': array(['New York'], dtype=object),
#  'East Elmhurst': array(['New York', nan], dtype=object),
#  'New Springville': array(['New York'], dtype=object),
#  'Arverne': array(['New York'], dtype=object),
#  'Gravesend': array(['New York'], dtype=object),
#  'Cambria Heights': array(['New York', nan], dtype=object),
#  'Tottenville': array(['New York'], dtype=object),
#  'Mariners Harbor': array(['New York'], dtype=object),
#  'Borough Park': array(['New York', nan], dtype=object),
#  'Bayside': array(['New York'], dtype=object),
#  'Downtown Brooklyn': array(['New York'], dtype=object),
#  'Port Morris': array(['New York'], dtype=object),
#  'Fieldston': array(['New York'], dtype=object),
#  'Kew Gardens': array(['New York'], dtype=object),
#  'College Point': array(['New York'], dtype=object),
#  'Mount Eden': array(['New York'], dtype=object),
#  'City Island': array(['New York'], dtype=object),
#  'Glendale': array(['New York'], dtype=object),
#  'Port Richmond': array(['New York'], dtype=object),
#  'Red Hook': array(['New York'], dtype=object),
#  'Queens Village': array(['New York'], dtype=object),
#  'Mott Haven': array(['New York'], dtype=object),
#  'Maspeth': array(['New York', 'South Bay, CA', nan], dtype=object),
#  'Williamsbridge': array(['New York'], dtype=object),
#  'Soundview': array(['New York'], dtype=object),
#  'Woodhaven': array(['New York'], dtype=object),
#  'Woodrow': array(['New York'], dtype=object),
#  'Co-op City': array(['New York'], dtype=object),
#  'Stuyvesant Town': array(['New York'], dtype=object),
#  'Parkchester': array(['New York'], dtype=object),
#  'North Riverdale': array(['New York'], dtype=object),
#  'Howard Beach': array(['New York'], dtype=object),
#  'Dyker Heights': array(['New York'], dtype=object),
#  'Bronxdale': array(['New York'], dtype=object),
#  'Sea Gate': array(['New York', 'Adirondacks'], dtype=object),
#  'Riverdale': array(['New York'], dtype=object),
#  'Bay Terrace': array(['New York'], dtype=object),
#  'Whitestone': array(['New York'], dtype=object),
#  'Fordham': array(['New York'], dtype=object),
#  'Bayswater': array(['New York'], dtype=object),
#  'Brownsville': array(['New York'], dtype=object),
#  'Wakefield': array(['New York'], dtype=object),
#  'Navy Yard': array(['New York'], dtype=object),
#  'Mount Hope': array(['New York'], dtype=object),
#  'Norwood': array(['New York'], dtype=object),
#  'Lighthouse Hill': array(['New York'], dtype=object),
#  'Unionport': array(['New York'], dtype=object),
#  'Springfield Gardens': array(['New York', 'Cuba'], dtype=object),
#  'Belle Harbor': array(['New York'], dtype=object),
#  'Corona': array(['New York', nan], dtype=object),
#  'Kew Gardens Hills': array(['New York'], dtype=object),
#  'Jamaica Estates': array(['New York'], dtype=object),
#  'Van Nest': array(['New York'], dtype=object),
#  'Fresh Meadows': array(['New York', 'Other (Domestic)'], dtype=object),
#  'Far Rockaway': array(['New York'], dtype=object),
#  'Morris Park': array(['New York'], dtype=object),
#  'West Brighton': array(['New York'], dtype=object),
#  'South Ozone Park': array(['New York'], dtype=object),
#  'Tremont': array(['New York'], dtype=object),
#  'Great Kills': array(['New York'], dtype=object),
#  'Manhattan Beach': array(['New York'], dtype=object),
#  'East Morrisania': array(['New York'], dtype=object),
#  'Marble Hill': array(['New York', 'Other (Domestic)'], dtype=object),
#  'Castleton Corners': array(['New York'], dtype=object),
#  'Dongan Hills': array(['New York'], dtype=object),
#  'Hunts Point': array(['New York'], dtype=object),
#  'Randall Manor': array(['New York'], dtype=object),
#  'Throgs Neck': array(['New York'], dtype=object),
#  'Todt Hill': array(['New York'], dtype=object),
#  'West Farms': array(['New York'], dtype=object),
#  'Bath Beach': array(['New York'], dtype=object),
#  'Concord': array(['New York'], dtype=object),
#  'Morrisania': array(['New York'], dtype=object),
#  'Laurelton': array(['New York'], dtype=object),
#  'Silver Lake': array(['New York'], dtype=object),
#  'Grymes Hill': array(['New York'], dtype=object),
#  'Holliswood': array(['New York'], dtype=object),
#  'Pelham Gardens': array(['New York'], dtype=object),
#  'Belmont': array(['New York'], dtype=object),
#  'Rosedale': array(['New York'], dtype=object),
#  'Pelham Bay': array(['New York'], dtype=object),
#  'New Brighton': array(['New York'], dtype=object),
#  'Midland Beach': array(['New York'], dtype=object),
#  'Baychester': array(['New York'], dtype=object),
#  'Spuyten Duyvil': array(['New York'], dtype=object),
#  'Bergen Beach': array(['New York'], dtype=object),
#  'Richmondtown': array(['New York'], dtype=object),
#  'Claremont Village': array(['New York'], dtype=object),
#  'Edgemere': array(['New York'], dtype=object),
#  'Howland Hook': array(['New York'], dtype=object),
#  'Melrose': array(['New York'], dtype=object),
#  'Schuylerville': array(['New York'], dtype=object),
#  'Coney Island': array(['New York'], dtype=object),
#  'New Dorp Beach': array(['New York'], dtype=object),
#  'South Beach': array(['New York'], dtype=object),
#  'Eltingville': array(['New York'], dtype=object),
#  'Oakwood': array(['New York'], dtype=object),
#  'Castle Hill': array(['New York'], dtype=object),
#  'Huguenot': array(['New York'], dtype=object),
#  'Olinville': array(['New York'], dtype=object),
#  'Edenwald': array(['New York'], dtype=object),
#  'Grant City': array(['New York'], dtype=object),
#  'Emerson Hill': array(['New York'], dtype=object),
#  'Westerleigh': array(['New York'], dtype=object),
#  'Neponsit': array(['New York'], dtype=object),
#  'Bay Terrace, Staten Island': array(['New York'], dtype=object),
#  'Jamaica Hills': array(['New York'], dtype=object),
#  'Fort Wadsworth': array(['New York'], dtype=object),
#  'Westchester Square': array(['New York'], dtype=object),
#  'Bellerose': array(['New York'], dtype=object),
#  "Bull's Head": array(['New York'], dtype=object),
#  'Mill Basin': array(['New York'], dtype=object),
#  'Hollis': array(['New York'], dtype=object),
#  'Gerritsen Beach': array(['New York'], dtype=object),
#  'Breezy Point': array(['New York'], dtype=object),
#  "Prince's Bay": array(['New York'], dtype=object),
#  'Willowbrook': array(['New York'], dtype=object),
#  'Rosebank': array(['New York'], dtype=object),
#  'Arden Heights': array(['New York'], dtype=object),
#  'New Dorp': array(['New York'], dtype=object)}

# %% [markdown]
# Fill the market using the neighbourhood_cleansed column

# %%
def impute_market(row):
    if type(row["market"]) != type("a"):
        nb_cleansed = row["neighbourhood_cleansed"]
        val = map_nbc_market[nb_cleansed][0]
        return val
    else:
        return row
    return row

listings["market"] = listings[["market", "neighbourhood_cleansed"]].apply(impute_market, axis=1)

# %% [markdown]
# ### host_location and host_neighbourhood

# %%
listings["host_location"].fillna("XX", inplace=True)

# %%
listings["host_neighbourhood"].fillna("XX", inplace=True)

# %% [markdown]
# ### neighbourhood

# %% [markdown]
# It might be safer to set the missing values in this column with the same ones from "neighbourhood_cleansed"

# %%
listings["neighbourhood"].fillna(listings["neighbourhood_cleansed"], inplace=True)

# %% [markdown]
# ### Zipcode

# %%
len(listings["zipcode"].unique())
# Out:
# 378

# %%
listings["zipcode"].fillna("XX", inplace=True)

# %% [markdown]
# ## First review and last review

# %% [markdown]
# Date columns. Why are there missing values?

# %%
review_date_cols = ["first_review", "last_review"]
nan_df = analyse_nans(listings)

# Verify that these columns have missing values in the exact same rows.
print("Number of rows between pairs of columns that have NaNs only in one of them - ")
for i in range(1, len(review_date_cols)):
    print(review_date_cols[i], "\t", review_date_cols[i-1], end=" -->\t ")
    idx1 = nan_df[review_date_cols[i-1]].iloc[2]
    idx2 = nan_df[review_date_cols[i]].iloc[2]
    l = find_unique_elems([idx1, idx2])
    print(len(l), "rows, \ti.e.", round(100*len(l)/listings.shape[0], 2), "% of total listings rows")
# Out:
# Number of rows between pairs of columns that have NaNs only in one of them -
# last_review 	 first_review -->	 0 rows, 	i.e. 0.0 % of total listings rows

# %%
listings[(~listings["last_review"].isna())&(listings["first_review"].isna()) |\
        (~listings["first_review"].isna())&(listings["last_review"].isna())]
# Out:
# Empty DataFrame
# Columns: [has_availability, neighbourhood_cleansed, maximum_minimum_nights, maximum_nights_avg_ntm, neighbourhood_group_cleansed, first_review, review_scores_communication, review_scores_rating, minimum_nights_avg_ntm, number_of_reviews_ltm, calendar_last_scraped, availability_30, calculated_host_listings_count_shared_rooms, calculated_host_listings_count_entire_homes, market, availability_90, number_of_reviews, maximum_maximum_nights, requires_license, country, minimum_minimum_nights, latitude, maximum_nights, neighbourhood, city, review_scores_location, host_location, state, review_scores_cleanliness, availability_60, country_code, review_scores_accuracy, review_scores_checkin, minimum_nights, minimum_maximum_nights, calendar_updated, smart_location, host_since, longitude, review_scores_value, calculated_host_listings_count_private_rooms, availability_365, host_neighbourhood, last_review, zipcode]
# Index: []

# %%
listings['last_review'] = pd.to_datetime(listings['last_review'])
listings['lreview_year'] = listings['last_review'].dt.year
listings['lreview_month'] = listings['last_review'].dt.month
listings['lreview_day'] = listings['last_review'].dt.day

listings['first_review'] = pd.to_datetime(listings['first_review'])
listings['freview_year'] = listings['first_review'].dt.year
listings['freview_month'] = listings['first_review'].dt.month
listings['freview_day'] = listings['first_review'].dt.day

# %%
cols = ["last_review", 'lreview_year', 'lreview_month', 'lreview_day']
listings[cols].describe()
# Out:
#        lreview_year  lreview_month   lreview_day
# count  39931.000000   39931.000000  39931.000000
# mean    2017.998247       5.644687     14.929178
# std        1.133024       4.536616     10.082954
# min     2010.000000       1.000000      1.000000
# 25%     2018.000000       1.000000      5.000000
# 50%     2018.000000       5.000000     15.000000
# 75%     2019.000000      10.000000     24.000000
# max     2019.000000      12.000000     31.000000

# %%
f, ax = plt.subplots(1, 3, figsize=(25, 5))
sns.distplot(a=listings[~listings["lreview_year"].isna()]["lreview_year"], ax=ax[0], kde=False)
sns.distplot(a=listings[~listings["lreview_month"].isna()]["lreview_month"], ax=ax[1], kde=False)
sns.distplot(a=listings[~listings["lreview_day"].isna()]["lreview_day"], ax=ax[2], kde=False)

# %% [markdown]
# If we use median, we can estimate that the missing year values is (most probably) 2018, the missing month values is (most probably) 10/11 and for date would be around 16.
#
# Or we can create a separate category called X for each column, to estimate that there has been no review written for those dates yet.Upon checking online using the URLs provided, we can verify that no reviews are provided for those listings yet.
#
# The latter method is used for imputation here.

# %%
listings["lreview_year"].apply(type)
# Out:
# 0        <class 'float'>
# 1        <class 'float'>
# 2        <class 'float'>
# 3        <class 'float'>
# 4        <class 'float'>
# 5        <class 'float'>
# 6        <class 'float'>
# 7        <class 'float'>
# 8        <class 'float'>
# 9        <class 'float'>
# 10       <class 'float'>
# 11       <class 'float'>
# 12       <class 'float'>
# 13       <class 'float'>
# 14       <class 'float'>
# 15       <class 'float'>
# 16       <class 'float'>
# 17       <class 'float'>
# 18       <class 'float'>
# 19       <class 'float'>
# 20       <class 'float'>
# 21       <class 'float'>
# 22       <class 'float'>
# 23       <class 'float'>
# 24       <class 'float'>
# 25       <class 'float'>
# 26       <class 'float'>
# 27       <class 'float'>
# 28       <class 'float'>
# 29       <class 'float'>
# 30       <class 'float'>
# 31       <class 'float'>
# 32       <class 'float'>
# 33       <class 'float'>
# 34       <class 'float'>
# 35       <class 'float'>
# 36       <class 'float'>
# 37       <class 'float'>
# 38       <class 'float'>
# 39       <class 'float'>
# 40       <class 'float'>
# 41       <class 'float'>
# 42       <class 'float'>
# 43       <class 'float'>
# 44       <class 'float'>
# 45       <class 'float'>
# 46       <class 'float'>
# 47       <class 'float'>
# 48       <class 'float'>
# 49       <class 'float'>
# 50       <class 'float'>
# 51       <class 'float'>
# 52       <class 'float'>
# 53       <class 'float'>
# 54       <class 'float'>
# 55       <class 'float'>
# 56       <class 'float'>
# 57       <class 'float'>
# 58       <class 'float'>
# 59       <class 'float'>
# 60       <class 'float'>
# 61       <class 'float'>
# 62       <class 'float'>
# 63       <class 'float'>
# 64       <class 'float'>
# 65       <class 'float'>
# 66       <class 'float'>
# 67       <class 'float'>
# 68       <class 'float'>
# 69       <class 'float'>
# 70       <class 'float'>
# 71       <class 'float'>
# 72       <class 'float'>
# 73       <class 'float'>
# 74       <class 'float'>
# 75       <class 'float'>
# 76       <class 'float'>
# 77       <class 'float'>
# 78       <class 'float'>
# 79       <class 'float'>
# 80       <class 'float'>
# 81       <class 'float'>
# 82       <class 'float'>
# 83       <class 'float'>
# 84       <class 'float'>
# 85       <class 'float'>
# 86       <class 'float'>
# 87       <class 'float'>
# 88       <class 'float'>
# 89       <class 'float'>
# 90       <class 'float'>
# 91       <class 'float'>
# 92       <class 'float'>
# 93       <class 'float'>
# 94       <class 'float'>
# 95       <class 'float'>
# 96       <class 'float'>
# 97       <class 'float'>
# 98       <class 'float'>
# 99       <class 'float'>
# 100      <class 'float'>
# 101      <class 'float'>
# 102      <class 'float'>
# 103      <class 'float'>
# 104      <class 'float'>
# 105      <class 'float'>
# 106      <class 'float'>
# 107      <class 'float'>
# 108      <class 'float'>
# 109      <class 'float'>
# 110      <class 'float'>
# 111      <class 'float'>
# 112      <class 'float'>
# 113      <class 'float'>
# 114      <class 'float'>
# 115      <class 'float'>
# 116      <class 'float'>
# 117      <class 'float'>
# 118      <class 'float'>
# 119      <class 'float'>
# 120      <class 'float'>
# 121      <class 'float'>
# 122      <class 'float'>
# 123      <class 'float'>
# 124      <class 'float'>
# 125      <class 'float'>
# 126      <class 'float'>
# 127      <class 'float'>
# 128      <class 'float'>
# 129      <class 'float'>
# 130      <class 'float'>
# 131      <class 'float'>
# 132      <class 'float'>
# 133      <class 'float'>
# 134      <class 'float'>
# 135      <class 'float'>
# 136      <class 'float'>
# 137      <class 'float'>
# 138      <class 'float'>
# 139      <class 'float'>
# 140      <class 'float'>
# 141      <class 'float'>
# 142      <class 'float'>
# 143      <class 'float'>
# 144      <class 'float'>
# 145      <class 'float'>
# 146      <class 'float'>
# 147      <class 'float'>
# 148      <class 'float'>
# 149      <class 'float'>
# 150      <class 'float'>
# 151      <class 'float'>
# 152      <class 'float'>
# 153      <class 'float'>
# 154      <class 'float'>
# 155      <class 'float'>
# 156      <class 'float'>
# 157      <class 'float'>
# 158      <class 'float'>
# 159      <class 'float'>
# 160      <class 'float'>
# 161      <class 'float'>
# 162      <class 'float'>
# 163      <class 'float'>
# 164      <class 'float'>
# 165      <class 'float'>
# 166      <class 'float'>
# 167      <class 'float'>
# 168      <class 'float'>
# 169      <class 'float'>
# 170      <class 'float'>
# 171      <class 'float'>
# 172      <class 'float'>
# 173      <class 'float'>
# 174      <class 'float'>
# 175      <class 'float'>
# 176      <class 'float'>
# 177      <class 'float'>
# 178      <class 'float'>
# 179      <class 'float'>
# 180      <class 'float'>
# 181      <class 'float'>
# 182      <class 'float'>
# 183      <class 'float'>
# 184      <class 'float'>
# 185      <class 'float'>
# 186      <class 'float'>
# 187      <class 'float'>
# 188      <class 'float'>
# 189      <class 'float'>
# 190      <class 'float'>
# 191      <class 'float'>
# 192      <class 'float'>
# 193      <class 'float'>
# 194      <class 'float'>
# 195      <class 'float'>
# 196      <class 'float'>
# 197      <class 'float'>
# 198      <class 'float'>
# 199      <class 'float'>
# 200      <class 'float'>
# 201      <class 'float'>
# 202      <class 'float'>
# 203      <class 'float'>
# 204      <class 'float'>
# 205      <class 'float'>
# 206      <class 'float'>
# 207      <class 'float'>
# 208      <class 'float'>
# 209      <class 'float'>
# 210      <class 'float'>
# 211      <class 'float'>
# 212      <class 'float'>
# 213      <class 'float'>
# 214      <class 'float'>
# 215      <class 'float'>
# 216      <class 'float'>
# 217      <class 'float'>
# 218      <class 'float'>
# 219      <class 'float'>
# 220      <class 'float'>
# 221      <class 'float'>
# 222      <class 'float'>
# 223      <class 'float'>
# 224      <class 'float'>
# 225      <class 'float'>
# 226      <class 'float'>
# 227      <class 'float'>
# 228      <class 'float'>
# 229      <class 'float'>
# 230      <class 'float'>
# 231      <class 'float'>
# 232      <class 'float'>
# 233      <class 'float'>
# 234      <class 'float'>
# 235      <class 'float'>
# 236      <class 'float'>
# 237      <class 'float'>
# 238      <class 'float'>
# 239      <class 'float'>
# 240      <class 'float'>
# 241      <class 'float'>
# 242      <class 'float'>
# 243      <class 'float'>
# 244      <class 'float'>
# 245      <class 'float'>
# 246      <class 'float'>
# 247      <class 'float'>
# 248      <class 'float'>
# 249      <class 'float'>
#               ...
# 49978    <class 'float'>
# 49979    <class 'float'>
# 49980    <class 'float'>
# 49981    <class 'float'>
# 49982    <class 'float'>
# 49983    <class 'float'>
# 49984    <class 'float'>
# 49985    <class 'float'>
# 49986    <class 'float'>
# 49987    <class 'float'>
# 49988    <class 'float'>
# 49989    <class 'float'>
# 49990    <class 'float'>
# 49991    <class 'float'>
# 49992    <class 'float'>
# 49993    <class 'float'>
# 49994    <class 'float'>
# 49995    <class 'float'>
# 49996    <class 'float'>
# 49997    <class 'float'>
# 49998    <class 'float'>
# 49999    <class 'float'>
# 50000    <class 'float'>
# 50001    <class 'float'>
# 50002    <class 'float'>
# 50003    <class 'float'>
# 50004    <class 'float'>
# 50005    <class 'float'>
# 50006    <class 'float'>
# 50007    <class 'float'>
# 50008    <class 'float'>
# 50009    <class 'float'>
# 50010    <class 'float'>
# 50011    <class 'float'>
# 50012    <class 'float'>
# 50013    <class 'float'>
# 50014    <class 'float'>
# 50015    <class 'float'>
# 50016    <class 'float'>
# 50017    <class 'float'>
# 50018    <class 'float'>
# 50019    <class 'float'>
# 50020    <class 'float'>
# 50021    <class 'float'>
# 50022    <class 'float'>
# 50023    <class 'float'>
# 50024    <class 'float'>
# 50025    <class 'float'>
# 50026    <class 'float'>
# 50027    <class 'float'>
# 50028    <class 'float'>
# 50029    <class 'float'>
# 50030    <class 'float'>
# 50031    <class 'float'>
# 50032    <class 'float'>
# 50033    <class 'float'>
# 50034    <class 'float'>
# 50035    <class 'float'>
# 50036    <class 'float'>
# 50037    <class 'float'>
# 50038    <class 'float'>
# 50039    <class 'float'>
# 50040    <class 'float'>
# 50041    <class 'float'>
# 50042    <class 'float'>
# 50043    <class 'float'>
# 50044    <class 'float'>
# 50045    <class 'float'>
# 50046    <class 'float'>
# 50047    <class 'float'>
# 50048    <class 'float'>
# 50049    <class 'float'>
# 50050    <class 'float'>
# 50051    <class 'float'>
# 50052    <class 'float'>
# 50053    <class 'float'>
# 50054    <class 'float'>
# 50055    <class 'float'>
# 50056    <class 'float'>
# 50057    <class 'float'>
# 50058    <class 'float'>
# 50059    <class 'float'>
# 50060    <class 'float'>
# 50061    <class 'float'>
# 50062    <class 'float'>
# 50063    <class 'float'>
# 50064    <class 'float'>
# 50065    <class 'float'>
# 50066    <class 'float'>
# 50067    <class 'float'>
# 50068    <class 'float'>
# 50069    <class 'float'>
# 50070    <class 'float'>
# 50071    <class 'float'>
# 50072    <class 'float'>
# 50073    <class 'float'>
# 50074    <class 'float'>
# 50075    <class 'float'>
# 50076    <class 'float'>
# 50077    <class 'float'>
# 50078    <class 'float'>
# 50079    <class 'float'>
# 50080    <class 'float'>
# 50081    <class 'float'>
# 50082    <class 'float'>
# 50083    <class 'float'>
# 50084    <class 'float'>
# 50085    <class 'float'>
# 50086    <class 'float'>
# 50087    <class 'float'>
# 50088    <class 'float'>
# 50089    <class 'float'>
# 50090    <class 'float'>
# 50091    <class 'float'>
# 50092    <class 'float'>
# 50093    <class 'float'>
# 50094    <class 'float'>
# 50095    <class 'float'>
# 50096    <class 'float'>
# 50097    <class 'float'>
# 50098    <class 'float'>
# 50099    <class 'float'>
# 50100    <class 'float'>
# 50101    <class 'float'>
# 50102    <class 'float'>
# 50103    <class 'float'>
# 50104    <class 'float'>
# 50105    <class 'float'>
# 50106    <class 'float'>
# 50107    <class 'float'>
# 50108    <class 'float'>
# 50109    <class 'float'>
# 50110    <class 'float'>
# 50111    <class 'float'>
# 50112    <class 'float'>
# 50113    <class 'float'>
# 50114    <class 'float'>
# 50115    <class 'float'>
# 50116    <class 'float'>
# 50117    <class 'float'>
# 50118    <class 'float'>
# 50119    <class 'float'>
# 50120    <class 'float'>
# 50121    <class 'float'>
# 50122    <class 'float'>
# 50123    <class 'float'>
# 50124    <class 'float'>
# 50125    <class 'float'>
# 50126    <class 'float'>
# 50127    <class 'float'>
# 50128    <class 'float'>
# 50129    <class 'float'>
# 50130    <class 'float'>
# 50131    <class 'float'>
# 50132    <class 'float'>
# 50133    <class 'float'>
# 50134    <class 'float'>
# 50135    <class 'float'>
# 50136    <class 'float'>
# 50137    <class 'float'>
# 50138    <class 'float'>
# 50139    <class 'float'>
# 50140    <class 'float'>
# 50141    <class 'float'>
# 50142    <class 'float'>
# 50143    <class 'float'>
# 50144    <class 'float'>
# 50145    <class 'float'>
# 50146    <class 'float'>
# 50147    <class 'float'>
# 50148    <class 'float'>
# 50149    <class 'float'>
# 50150    <class 'float'>
# 50151    <class 'float'>
# 50152    <class 'float'>
# 50153    <class 'float'>
# 50154    <class 'float'>
# 50155    <class 'float'>
# 50156    <class 'float'>
# 50157    <class 'float'>
# 50158    <class 'float'>
# 50159    <class 'float'>
# 50160    <class 'float'>
# 50161    <class 'float'>
# 50162    <class 'float'>
# 50163    <class 'float'>
# 50164    <class 'float'>
# 50165    <class 'float'>
# 50166    <class 'float'>
# 50167    <class 'float'>
# 50168    <class 'float'>
# 50169    <class 'float'>
# 50170    <class 'float'>
# 50171    <class 'float'>
# 50172    <class 'float'>
# 50173    <class 'float'>
# 50174    <class 'float'>
# 50175    <class 'float'>
# 50176    <class 'float'>
# 50177    <class 'float'>
# 50178    <class 'float'>
# 50179    <class 'float'>
# 50180    <class 'float'>
# 50181    <class 'float'>
# 50182    <class 'float'>
# 50183    <class 'float'>
# 50184    <class 'float'>
# 50185    <class 'float'>
# 50186    <class 'float'>
# 50187    <class 'float'>
# 50188    <class 'float'>
# 50189    <class 'float'>
# 50190    <class 'float'>
# 50191    <class 'float'>
# 50192    <class 'float'>
# 50193    <class 'float'>
# 50194    <class 'float'>
# 50195    <class 'float'>
# 50196    <class 'float'>
# 50197    <class 'float'>
# 50198    <class 'float'>
# 50199    <class 'float'>
# 50200    <class 'float'>
# 50201    <class 'float'>
# 50202    <class 'float'>
# 50203    <class 'float'>
# 50204    <class 'float'>
# 50205    <class 'float'>
# 50206    <class 'float'>
# 50207    <class 'float'>
# 50208    <class 'float'>
# 50209    <class 'float'>
# 50210    <class 'float'>
# 50211    <class 'float'>
# 50212    <class 'float'>
# 50213    <class 'float'>
# 50214    <class 'float'>
# 50215    <class 'float'>
# 50216    <class 'float'>
# 50217    <class 'float'>
# 50218    <class 'float'>
# 50219    <class 'float'>
# 50220    <class 'float'>
# 50221    <class 'float'>
# 50222    <class 'float'>
# 50223    <class 'float'>
# 50224    <class 'float'>
# 50225    <class 'float'>
# 50226    <class 'float'>
# 50227    <class 'float'>
# Name: lreview_year, Length: 50220, dtype: object

# %%
listings["first_review"].fillna("XX", inplace=True)
listings["last_review"].fillna("XX", inplace=True)
listings['lreview_year'].fillna(0, inplace=True)
listings['lreview_month'].fillna(0, inplace=True)
listings['lreview_day'].fillna(0, inplace=True)
listings['freview_year'].fillna(0, inplace=True)
listings['freview_month'].fillna(0, inplace=True)
listings['freview_day'].fillna(0, inplace=True)

# %%
listings['ndays_between_f_l_reviews'] = abs(listings['lreview_day'] - listings['freview_day'])

# %%
listings

# %%
listings['ndays_between_f_l_reviews'].head()
# Out:
# 0     0.0
# 1    15.0
# 2    19.0
# 3     3.0
# 4     0.0
# Name: ndays_between_f_l_reviews, dtype: float64

# %%
plot_nans(listings)
